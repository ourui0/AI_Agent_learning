# %%
import torch

# %%
# 定义数据
x = torch.randn(3,5)
print(x)
# Out:
# tensor([[ 0.8780,  0.1097, -1.0065, -1.1532, -0.2849],
#         [ 0.2186,  0.2969,  0.3095, -0.9268,  0.4134],
#         [-1.0168, -0.1260,  0.0958,  1.0808,  0.5593]])

# %%
y_prob = torch.softmax(x,dim = 1)
print(y_prob)
# Out:
# tensor([[0.4856, 0.2252, 0.0738, 0.0637, 0.1518],
#         [0.2123, 0.2296, 0.2325, 0.0675, 0.2580],
#         [0.0514, 0.1252, 0.1563, 0.4186, 0.2485]])
